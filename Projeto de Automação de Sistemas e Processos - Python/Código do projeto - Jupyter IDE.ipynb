# %% [markdown]
# # Automação de Sistemas e Processos com Python
#
# ### Projeto:
#
# Todos os dias, o sistema irá atualizar as vendas do dia anterior.
# Este projeto é capaz de enviar um e-mail para a diretoria da empresa no qual o usuário trabalha, com o faturamento e a quantidade de produtos vendidos no dia anterior
#
# E-mail da diretoria: emailteste@gmail.com<br>
# Local onde o sistema disponibiliza as vendas do dia anterior:
# https://drive.google.com/drive/folders/1tJMNKc7-VPs_GYZgsS7xSvBRddZhWEL_?usp=sharing

# %%
# !pip install pyautogui

# %%
import pyautogui
import pyperclip
import time

pyautogui.PAUSE = 1

pyautogui.hotkey('ctrl', 't')
pyperclip.copy('https://drive.google.com/drive/folders/1tJMNKc7-VPs_GYZgsS7xSvBRddZhWEL_?usp=sharing')
pyautogui.hotkey('ctrl', 'v')
pyautogui.press('enter')

time.sleep(2)
pyautogui.click(x=651, y=456, clicks=2)

time.sleep(3)
pyautogui.click(x=644, y=596)
time.sleep(1)
pyautogui.click(x=1611, y=284)
time.sleep(2)
pyautogui.click(x=1326, y=835)
time.sleep(5)

import pandas as pd

tabela = pd.read_excel(r"C:\Users\David\Downloads\Planilhas - Vendas.xlsx")
display(tabela)

faturamento = tabela['Valor Final'].sum()
quantidade = tabela['Quantidade'].sum()

print(faturamento)
print(quantidade)

time.sleep(2)
pyautogui.hotkey('ctrl', 't')
pyperclip.copy('https://mail.google.com/mail/u/0/#inbox')
pyautogui.hotkey('ctrl', 'v')
pyautogui.press('enter')
time.sleep(3)
pyautogui.click(x=186, y=295)
pyautogui.write('kynben36@gmail.com')
pyautogui.press('tab')
time.sleep(1)
pyautogui.write('davinsouza08@gmail.com')
pyautogui.press('tab')
time.sleep(1)
pyautogui.press('tab')
pyperclip.copy('Relatório de Vendas')
pyautogui.hotkey('ctrl', 'v')
pyautogui.press('tab')

texto = f'''
Prezados,
como foi solicitado, venho por meio deste e-mail para informar o faturamento de ontem e a quantidade de produtos vendidos na nossa unidade.

O faturamento foi de R$ {faturamento:,.2f}.

O total de vendas foi de R$ {quantidade:,.2f}.

Abraços!
Davi Souza. '''

pyperclip.copy(texto)
pyautogui.hotkey('ctrl', 'v')
time.sleep(2)
pyautogui.hotkey('ctrl', 'enter')
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...
